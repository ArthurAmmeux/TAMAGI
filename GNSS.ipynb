# %% [markdown]
# # Fonctions terminées

# %% [markdown]
# Afin d'installer la bibliothèque openCV il faut lancer le code suivant:
#
# pip install opencv-python

# %%
# Libraries

import gzip
import requests
import pandas as pd
import shutil
import os
import zipfile
import tarfile
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pyl
import matplotlib as mpl
import cv2
from datetime import datetime
from datetime import timedelta

# %%
# ARCHIVE EXTENSIONS
ZIP_EXTENSION = ".zip"
TAR_EXTENSION = ".tar"
TAR_GZ_EXTENSION = ".tar.gz"
TGZ_EXTENSION = ".tgz"
GZ_EXTENSION = ".gz"

EMPTY_URL_ERROR = "ERROR: URL should not be empty."
FILENAME_ERROR = "ERROR: Filename should not be empty."
UNKNOWN_FORMAT = "ERROR: Unknown file format. Can't extract."

def download_dataset(url, target_path="temp_data/", keep_download=True, overwrite_download=False):
    """Downloads dataset from a url.
    url: string, a dataset path
    target_path: string, path where data will be downloaded
    keep_download: boolean, keeps the original file after extraction
    overwrite_download: boolean, stops download if dataset already exists
    """
    if url == "" or url is None:
        raise Exception(EMPTY_URL_ERROR)

    filename = get_filename(url)
    file_location = get_file_location(target_path, filename)

    os.makedirs(target_path, exist_ok=True)

    if os.path.exists(file_location) and not overwrite_download:
        print(f"File already exists at {file_location}. Use: 'overwrite_download=True' to \
overwrite download")
        extract_file(target_path, filename)
        return

    print(f"Downloading file from {url} to {file_location}.")
    # Download
    with open(file_location, 'wb') as f:
        with requests.get(url, allow_redirects=True, stream=True) as resp:
            for chunk in resp.iter_content(chunk_size = 512):  #chunk_size in bytes
                if chunk:
                    f.write(chunk)

    print("Finished downloading.")
    print("Extracting the file now ...")
    extract_file(target_path, filename)

    if not keep_download:
        os.remove(file_location)

def extract_file(target_path, filename):
	"""Extract file based on file extension
	target_path: string, location where data will be extracted
	filename: string, name of the file along with extension
	"""
	if filename == "" or filename is None:
		raise Exception(FILENAME_ERROR)

	file_location = get_file_location(target_path, filename)

	if filename.endswith(ZIP_EXTENSION):
		print("Extracting zip file...")
		zipf = zipfile.ZipFile(file_location, 'r')
		zipf.extractall(target_path)
		zipf.close()
	elif filename.endswith(TAR_EXTENSION) or \
		 filename.endswith(TAR_GZ_EXTENSION) or \
		 filename.endswith(TGZ_EXTENSION):
		print("Extracting tar file")
		tarf = tarfile.open(file_location, 'r')
		tarf.extractall(target_path)
		tarf.close()
	elif filename.endswith(GZ_EXTENSION):
		with gzip.open(file_location, 'r') as f_in, open(file_location[:-2] + 'dat', 'wb') as f_out:
			shutil.copyfileobj(f_in, f_out)
	else:
		print(UNKNOWN_FORMAT)

def silent_download_dataset(url, target_path="temp_data/", keep_download=True, overwrite_download=False):
    """Downloads dataset from a url.
    url: string, a dataset path
    target_path: string, path where data will be downloaded
    keep_download: boolean, keeps the original file after extraction
    overwrite_download: boolean, stops download if dataset already exists
    """
    if url == "" or url is None:
        raise Exception(EMPTY_URL_ERROR)

    filename = get_filename(url)
    file_location = get_file_location(target_path, filename)

    os.makedirs(target_path, exist_ok=True)

    if os.path.exists(file_location) and not overwrite_download:
        extract_file(target_path, filename)
        return


    # Download
    with open(file_location, 'wb') as f:
        with requests.get(url, allow_redirects=True, stream=True) as resp:
            for chunk in resp.iter_content(chunk_size = 512):  #chunk_size in bytes
                if chunk:
                    f.write(chunk)
    extract_file(target_path, filename)

    if not keep_download:
        os.remove(file_location)


def get_filename(url):
	"""Extract filename from file url"""
	filename = os.path.basename(url)
	return filename

def get_file_location(target_path, filename):
	""" Concatenate download directory and filename"""
	return target_path + filename

# %%
#Fonction

def read_datfile(filepath, image=False):

    ##  Fonction qui permet d'extraire les données des fichiers dat JRC en array. 

    # str filepath: emplacement du fichier
    # boolean image: active ou non l'affichage de l'array sous forme d'image

    ##

  X = np.loadtxt(filepath, dtype = str, skiprows=32)

  d1 = len(X)
  d2 = len(X[0].split(sep = ','))

  Y = np.zeros((d1,d2))

  for i in range (d1):
    Y[i,:] = X[i].split(sep = ',')

  Z = Y.astype('float')
  Z =  np.flipud(Z)

  if image:
    plt.imshow(Z)
    plt.colorbar()

  return(Z)

def read_url(url, image = False):

  download_dataset(url, target_path="data/")
  filepath = "data/" + url[82:-3]
  Z = read_datfile(filepath, image)

  return (Z)

def silent_read_url(url, image = False):

  silent_download_dataset(url, target_path="temp_data/")
  filepath = "temp_data/" + url[82:-3]
  Z = read_datfile(filepath, image)

  return (Z)

# %%
def build_url(data, forecast, date):

  #renvoie l'url correspondant en fonction des données et de la date demandées  
  #data: int, 0 pour PLL error et 1 pour lost-of-lock probability
  #forecast: int, 0 pour nowcasting et 1 pour forecast
  #year, string de longueur 4
  #month, doy, day, hour, min, string de longueur 2
  year = date.strftime('%Y')
  month = date.strftime('%m')
  day = date.strftime('%d')
  doy = date.strftime('%j')
  hour = date.strftime('%H')
  min = date.strftime('%M')

  url_root = 'https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/'

  url_date1 = year + '/' + doy + '/'
  datanames = [['RPF3_PE-NOWGLOA_','RPF3_LLP-NOWGLOA_'],['RPF3_PE-LTF24HGLOA_','RPF3_LLP-LTF24HGLOA_']]
  url_data = datanames[forecast][data]
  url_date2 = year[2:] + month + day
  url = url_root + url_date1 + url_data + url_date2 + hour + min + '00.gz'
  return(url)

def get_last_url(data, forecast):
  statut = 404
  date = datetime.utcnow()
  i = 0;
  while statut != 200:
    url = build_url(data,0,date)
    statut = requests.get(url).status_code
    date = date-timedelta(minutes=1)
  return(url)

def print_last_data(data, forecast):
  url = get_last_url(data,forecast)
  array = read_url(url)

  dataname= ['Scintillation impact on positionning error', 'Lost-of-lock probability ']
  forecastname= ['nowcasting, ','forecast, ']
  txt = '20'+url[-15:-13]+'/'+url[-13:-11]+'/'+url[-11:-9]+' at '+url[-9:-7]+':'+url[-7:-5]
  
  plt.figure()
  plt.imshow(array)
  plt.title(dataname[data]+forecastname[forecast]+txt)
  plt.colorbar()

# %%
def get_last_url2(data, forecast):

  statut = 404
  date = datetime.utcnow()
  i = 0;

  m = date.minute

  if forecast:
    date = date-timedelta(minutes=m)+timedelta(days=1)-timedelta(hours=date.hour%3)


    while statut != 200:
      url = build_url(data,forecast,date)
      statut = requests.get(url).status_code
      date = date-timedelta(hours=3)


  else: 
    if m>=43:
      dt = m-43
    elif m>=13:
      dt = m-13
    else:
      dt = m+17

    date = date-timedelta(minutes=dt)

    
    while statut != 200:
      url = build_url(data,forecast,date)
      statut = requests.get(url).status_code
      date = date-timedelta(minutes=1)

      if statut==200:
        return(url)

      url = build_url(data,forecast,date)
      statut = requests.get(url).status_code
      date = date-timedelta(minutes=29)

  return(url)

def print_last_data2(data, forecast):
  url = get_last_url2(data,forecast)
  array = read_url(url)

  dataname= ['Scintillation impact on positioning error ', 'Lost-of-lock probability ']
  forecastname= ['nowcasting, ','forecast, ']
  txt = '20'+url[-15:-13]+'-'+url[-13:-11]+'-'+url[-11:-9]+' at '+url[-9:-7]+':'+url[-7:-5]
  
  plt.figure()
  plt.imshow(array)
  plt.title(dataname[data]+forecastname[forecast]+txt)
  plt.colorbar()

# %%
def average2(A):
  [a,b] = A.shape

  average = np.nan

  n = 0
  S = 0

  for i in range(0,a):
    for j in range(0,b):
      if not np.isnan(A[i,j]):
        S += A[i,j]
        n += 1
  
  if n!=0: 
    average = S/n

  return(average)

def average_map(P):
  Z = np.zeros((6,8))
  (a,b) = P.shape

  res_lat = a/180
  res_long = b/360

  for i in range(0,6):
    for j in range(0,8):

      Z[i,j] = average2(P[int(30*i*res_lat):int(30*(i+1)*res_lat), int(45*j*res_long):int(45*(j+1)*res_long)])
  
  return(Z)

# %%
def indice1(P,R, alpha):
  b = 6.5
  I = b*((alpha*(P/100)**2 + (1-alpha)*(R)**2)**0.5);

  return(np.floor(I))

def indice2(P,R, alpha):
  b = 6.5
  I = b*((alpha*(P/100)**2 + (1-alpha)*(R)**2)**0.5);

  return(I)


def adapt_res(I, map):
  (a,b) = I.shape
  (c,d) = map.shape[:2]
  I2 = np.zeros((c,d))

  for i in range(a):
    for j in range (b):
      I2[int(i*c/a):(int(i*c/a)+int(c/a)),int(j*d/b):(int(j*d/b)+int(d/b))] = I[i][j]*np.ones((int(c/a),int(d/b))) 

  return(I2) 

def display_imap(forecast):
  url1 = get_last_url2(1,forecast)

  P = read_url(url1)
  R = read_url(get_last_url2(0,forecast))  
  
  str_date = "le "+url1[-11:-9]+"/"+url1[-13:-11]+"/20"+url1[-15:-13]+' à '+ url1[-9:-7]+':'+url1[-7:-5]

  P2 = average_map(P)
  R2 = average_map(R)

  im = cv2.imread("map.jpg")
  map = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

  I = indice1(P2, R2, 0.5)
  I2 = adapt_res(I, map)

  (sz1,sz2) = map.shape[:2]
  figsz = 10

  title1 = "Carte mondiale de l'indice GNSS N "
  figtitle = title1+str_date

  if forecast:
    figtitle+=', Prédiction'

  plt.figure(figsize = (figsz, figsz*sz2/sz1))
  plt.imshow(map)
  plt.imshow(I2, cmap = plt.cm.get_cmap('viridis', 6), alpha=0.6)
  plt.clim(-0.5, 5.5)
  plt.colorbar(fraction=0.019, pad=0.04)
  plt.title(figtitle)

# %% [markdown]
# # Exploitation donnée

# %%
def initiate_folders():
    
    d1 = datetime.utcnow()
    d2 = d1 - timedelta(days=1095)

    #initialisation des fichiers
    
    time = d1
    
    parent_dir = 'GNNS_index_data/'
    
    while time>d2:
         
        path = parent_dir + time.strftime("%Y/%m_%b")
        
        if not os.path.exists(path):
            
            os.makedirs(path)
        
        time = time - timedelta(days=1)

# %%
initiate_folders()

# %%
def download_GNSS_data(date1, date2):
    
    time = date1
    parent_dir = 'GNNS_index_data/'
    temp_datas = np.zeros((50,3))
    
    m = time.minute
    d = time.day
        
    im = cv2.imread("map.jpg")
    map = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    
    if m>=43:
        dt = m-43
    elif m>=13:
        dt = m-13
    else:
        dt = m+17
        
    time = time-timedelta(minutes=dt)
    
    i=0
    j=0
    deltaT = [1,29]
    
    statut = 404
    
    while time>date2:
        
        url1 = build_url(0,0,time)
        url2 = build_url(1,0,time)
        statut = requests.get(url1).status_code
        
        time = time-timedelta(minutes=deltaT[j%2])
        
        
        if statut == 200:
            
            print(url2)
            
            P = silent_read_url(url2)
            R = silent_read_url(url1)  

            P2 = average_map(P)
            R2 = average_map(R)
            I = indice2(P2, R2, 0.5)

            path = parent_dir + time.strftime("%Y/%m_%b/") 
            filename = (time+timedelta(days=1)).strftime("%d")+'.csv'

            if time.day != d:
                np.savetxt(path+filename,temp_datas, delimiter = ';')
                temp_datas = np.zeros((50,3))
                d = time.day
                i=0

            temp_datas[i,0] = time.hour
            temp_datas[i,1] = time.minute
            temp_datas[i,2] = average2(I)
            i = i + 1
            print(average2(I))
            
            filepath1 = "temp_data/" + url1[82:-3] 
            filepath2 = "temp_data/" + url2[82:-3]

            os.remove(filepath1+'.dat')
            os.remove(filepath2+'.dat')
            os.remove(filepath1+'.gz')
            os.remove(filepath2+'.gz')
            
        statut=404
        j=j+1

# %%
date1 = datetime.utcnow()
date2 = date1-timedelta(days=3) 


download_GNSS_data(date1,date2)
# Out:
# https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208144200.gz
# 0.12659992878594564
# https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208141200.gz
# 0.13017092154449542
# https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208134200.gz

# %%
print(1%2)
# Out:
# 1

# %%
urltest = 'https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208051300.gz'
download_dataset(urltest)
filepath = "temp_data/" + urltest[82:-3]
X = np.loadtxt(filepath, dtype = str, skiprows=32)
# Out:
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208051300.gz to temp_data/RPF3_LLP-NOWGLOA_230208051300.gz.
# Finished downloading.
# Extracting the file now ...

# %% [markdown]
# # Test Divers

# %%
print_last_data2(0,0)
# Out:
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/034/RPF3_PE-NOWGLOA_230203124300.gz to data/RPF3_PE-NOWGLOA_230203124300.gz.
# Finished downloading.
# Extracting the file now ...

# %%
display_imap(0)
# Out:
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208134200.gz to data/RPF3_LLP-NOWGLOA_230208134200.gz.
# Finished downloading.
# Extracting the file now ...
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_PE-NOWGLOA_230208134200.gz to data/RPF3_PE-NOWGLOA_230208134200.gz.
# Finished downloading.
# Extracting the file now ...

# %%
forecast=0
url1 = get_last_url2(1,forecast)

P = read_url(url1)
R = read_url(get_last_url2(0,forecast))  
  
str_date = "le "+url1[-11:-9]+"/"+url1[-13:-11]+"/20"+url1[-15:-13]+' à '+ url1[-9:-7]+':'+url1[-7:-5]

P2 = average_map(P)
R2 = average_map(R)

im = cv2.imread("map.jpg")
map = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

I = indice2(P2, R2, 0.5)
I2 = adapt_res(I, map)
    
(sz1,sz2) = map.shape[:2]
figsz = 10

title1 = "Carte mondiale de l'indice GNSS N "
figtitle = title1+str_date

plt.figure(figsize = (figsz, figsz*sz2/sz1))
plt.imshow(map)
plt.imshow(I2, cmap = plt.cm.get_cmap('viridis', 6), alpha=0.6)
plt.clim(-0.5, 5.5)
plt.colorbar(fraction=0.019, pad=0.04)
plt.title(figtitle)

print(average2(I))
# Out:
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_LLP-NOWGLOA_230208144200.gz to data/RPF3_LLP-NOWGLOA_230208144200.gz.
# Finished downloading.
# Extracting the file now ...
# Downloading file from https://ionospheric-prediction.jrc.ec.europa.eu/products/Ionosphere/RPF3/2023/039/RPF3_PE-NOWGLOA_230208144200.gz to data/RPF3_PE-NOWGLOA_230208144200.gz.
# Finished downloading.
# Extracting the file now ...
# 0.12659992878594564
